# %% [markdown]
# ## Settings and imports

# %%
import numpy as np
import pandas as pd
import os
import torch
import matplotlib.pyplot as plt
import string
from torch import nn
from torch.utils.data import Dataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import random

# %%
import json

with open('../config.json', 'r') as f:
    config = json.load(f)
    
preprocessing_method = config["preprocessing_method"] # normalization / logarithm
remove_outer = config["remove_outer"]
how_many_outer_to_remove = config["how_many_outer_to_remove"]
elements_to_keep = config["elements_to_keep"]

data_path = config["data_path"]
results_path = config["results_path"]
figures_path = config["figures_path"]
models_path = config["models_path"]

# %%
columns_to_keep_inds = [el + '_i' for el in elements_to_keep]
columns_to_keep_inks = [el + '_a' for el in elements_to_keep]

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv(data_path)
inks_df = df[[col for col in df.columns if col.endswith('_a')]]
inks_df.columns = [col.split('_')[0] for col in inks_df.columns]
inds_df = df[[col for col in df.columns if col.endswith('_i')]]
inds_df.columns = [col.split('_')[0] for col in inds_df.columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Joining corresponding samples from inds and inks into one table

# %%
inDKs_df = df

# %% [markdown]
# ### Keeping track of the records from the same sample

# %% [markdown]
# Check

# %%
all(inDKs_df['sample_i'] == inDKs_df['sample_a'])
# Out:
# True

# %% [markdown]
# We can use 'name' column as sample id:

# %%
inDKs_df['Sample_id'] = inDKs_df['sample_i']

# %%
################################################

# %% [markdown]
# ### Removing some data

# %% [markdown]
# 1. Let's remove 'outer' samples:

# %%
def remove_outer(group, n):
    return group.iloc[n:-n] if len(group) > 2*n else pd.DataFrame(columns=group.columns)

# %%
inDKs_df = inDKs_df.groupby('Sample_id', group_keys=False).apply(remove_outer, n=how_many_outer_to_remove)
# Out:
# /tmp/ipykernel_11161/3937849811.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   inDKs_df = inDKs_df.groupby('Sample_id', group_keys=False).apply(remove_outer, n=how_many_outer_to_remove)
# /tmp/ipykernel_11161/3937849811.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   inDKs_df = inDKs_df.groupby('Sample_id', group_keys=False).apply(remove_outer, n=how_many_outer_to_remove)

# %% [markdown]
# 2. Let's keep only columns that we need.

# %% [markdown]
# To reduce the set of used elements run cell below. Then, instead of predicting 29 numbers, we will predict only 8. We will also use only 8 numbers as input.

# %%
inDKs_df = inDKs_df[columns_to_keep_inks + columns_to_keep_inds + ['Sample_id', 'name'] ]

# %% [markdown]
# 3. Let's remove rows with missing values.

# %%
(inDKs_df.shape[0] - inDKs_df.dropna().shape[0])/inDKs_df.shape[0]
# Out:
# 0.0

# %% [markdown]
# 4. Let's set negative numbers to zeros.

# %%
for col in columns_to_keep_inks + columns_to_keep_inds:
    inDKs_df[col][inDKs_df[col] < 0] = 0
# Out:
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0
# /tmp/ipykernel_11161/1556174307.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   inDKs_df[col][inDKs_df[col] < 0] = 0

# %% [markdown]
# ### Normalization / taking logarithm

# %%
def adjusted_log_transform(input_array):
    res = np.where(input_array>0, np.log(input_array), 0)
    #res = np.where(input_array<=0, input_array + res.min(axis=0), res)
    return res

# %%
if preprocessing_method == 'logarithm':
    
    inDKs_df.iloc[:, 0:16] = adjusted_log_transform(inDKs_df.iloc[:, 0:16].values)
# Out:
# /tmp/ipykernel_11161/1905796701.py:2: RuntimeWarning: divide by zero encountered in log
#   res = np.where(input_array>0, np.log(input_array), 0)

# %%
import plotly.express as px
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(inDKs_df.iloc[:, 8:16].values)

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(inDKs_df.iloc[:, 8:16].values)

# %%
import numpy as np
import matplotlib.pyplot as plt

n_colors = inDKs_df['Sample_id'].nunique()

base_cmap = plt.get_cmap('hsv') 

colors = [base_cmap(i / n_colors) for i in range(n_colors)]

color_dict = dict(zip(np.random.permutation(inDKs_df['Sample_id'].unique()), colors))

# %%
#%matplotlib widget

# %%
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for i, name in enumerate(inDKs_df['Sample_id']):
    ax.plot(X_pca[i, 0], X_pca[i, 1], marker='o', linestyle='', ms=1, color=color_dict[name])
ax.legend()

plt.show()
# Out:
# /tmp/ipykernel_11161/1419193874.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ### Train test split, datasets, dataloaders

# %%
indices = list(range(int(inDKs_df.shape[0])))
ind_train_all, ind_test_all = train_test_split(indices, test_size=0.2, random_state=1)
ind_train_all, ind_val_all = train_test_split(ind_train_all, test_size=0.25, random_state=1)

partition = {'train': ind_train_all,
         'val': ind_val_all,
        'test': ind_test_all}

X_y_train = inDKs_df.iloc[partition['train'],:]
X_y_val = inDKs_df.iloc[partition['val'],:]
X_y_test = inDKs_df.iloc[partition['test'],:]

X_y_train.reset_index(drop=True, inplace=True)
X_y_val.reset_index(drop=True, inplace=True)
X_y_test.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Creating features and labels matrices

# %%
train_order = X_y_train['Sample_id']
val_order = X_y_val['Sample_id']
test_order = X_y_test['Sample_id']

X_train = np.array(X_y_train[columns_to_keep_inds].values)
y_train = np.array(X_y_train[columns_to_keep_inks].values)
X_val = np.array(X_y_val[columns_to_keep_inds].values)
y_val = np.array(X_y_val[columns_to_keep_inks].values)
X_test = np.array(X_y_test[columns_to_keep_inds].values)
y_test = np.array(X_y_test[columns_to_keep_inks].values)

# %%
fig, axes = plt.subplots(4, 2, figsize=(7, 7), sharey=True) 

axes = axes.flatten()

for i in range(8):
    axes[i].hist(X_train[:,i], bins=100)
    #axes[i].hist(y_test[:,i], bins=100)
    axes[i].set_title(elements_to_keep[i])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(4, 2, figsize=(7, 7), sharey=True) 

axes = axes.flatten()

for i in range(8):
    axes[i].hist(y_train[:,i], bins=100)
    #axes[i].hist(y_test[:,i], bins=100)
    axes[i].set_title(elements_to_keep[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalization / taking logarithm

# %%
#(np.where(X_train>0, res, res.min(axis=0)-np.log(res-res.min(axis=0))))[0,:]

# %%
def adjusted_log_transform(input_array):
    res = np.where(input_array>0, np.log(input_array), 0)
    #res = np.where(input_array<=0, input_array + res.min(axis=0), res)
    return res

# %%
if preprocessing_method == 'normalization':

    X_train = (X_train - np.min(X_train, axis=0))/np.std(X_train, axis=0)
    y_train = (y_train - np.min(y_train, axis=0))/np.std(y_train, axis=0)

    X_val = (X_val - np.min(X_val, axis=0))/np.std(X_val, axis=0)
    y_val = (y_val - np.min(y_val, axis=0))/np.std(y_val, axis=0)

    X_test = (X_test - np.min(X_test, axis=0))/np.std(X_test, axis=0)
    y_test = (y_test - np.min(y_test, axis=0))/np.std(y_test, axis=0)
    
elif preprocessing_method == 'logarithm':
    
    X_train = adjusted_log_transform(X_train)
    y_train = adjusted_log_transform(y_train)
    
    X_val = adjusted_log_transform(X_val)
    y_val = adjusted_log_transform(y_val)
    X_test = adjusted_log_transform(X_test)
    y_test = adjusted_log_transform(y_test)
    
elif preprocessing_method == 'logarithm_and_normalization':
    
    #logarithm
    X_train = adjusted_log_transform(X_train)
    y_train = adjusted_log_transform(y_train)
    
    X_val = adjusted_log_transform(X_val)
    y_val = adjusted_log_transform(y_val)
    X_test = adjusted_log_transform(X_test)
    y_test = adjusted_log_transform(y_test)
    
    #normalization
    X_train = (X_train - np.min(X_train, axis=0))/np.std(X_train, axis=0)
    y_train = (y_train - np.min(y_train, axis=0))/np.std(y_train, axis=0)

    X_val = (X_val - np.min(X_val, axis=0))/np.std(X_val, axis=0)
    y_val = (y_val - np.min(y_val, axis=0))/np.std(y_val, axis=0)

    X_test = (X_test - np.min(X_test, axis=0))/np.std(X_test, axis=0)
    y_test = (y_test - np.min(y_test, axis=0))/np.std(y_test, axis=0)
# Out:
# /tmp/ipykernel_11161/1905796701.py:2: RuntimeWarning: divide by zero encountered in log
#   res = np.where(input_array>0, np.log(input_array), 0)
# /tmp/ipykernel_11161/1905796701.py:2: RuntimeWarning: invalid value encountered in log
#   res = np.where(input_array>0, np.log(input_array), 0)

# %%
dim = 2
plt.hist(X_train[:,dim], bins=100);
plt.hist(X_test[:,dim], bins=100);
plt.hist(X_val[:,dim], bins=100);

#np.argwhere(X_train[:,2]<-20)

# %% [markdown]
# ### Converting to tensors

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
X_train = torch.Tensor(X_train).to(device)
y_train = torch.Tensor(y_train).to(device)
    
X_val = torch.Tensor(X_val).to(device)
y_val = torch.Tensor(y_val).to(device)
X_test = torch.Tensor(X_test).to(device)
y_test = torch.Tensor(y_test).to(device)

# %% [markdown]
# Cu >> Mn > Al > Zn > Pb > S > Cr > Co >>

# %% [markdown]
# ## Quality of prediction: closest points

# %% [markdown]
# #### Creating df with means of classes

# %%
elements_names = [el.split('_')[0] for el in columns_to_keep_inds]

# %%
train_val_df = pd.DataFrame(y_train.cpu())
train_val_df = pd.concat([train_val_df, 
                                    pd.DataFrame(y_val.cpu())])
train_val_df.columns = elements_names
train_val_df.insert(0, 'Sample_id', pd.concat([train_order, val_order]))
train_val_df.reset_index(drop=True, inplace=True)

# %%
mean_df = train_val_df[['Sample_id']]

for name in elements_names:
    mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
    mean_df.drop_duplicates('Sample_id', inplace=True)
    
mean_df.sort_values(by='Sample_id', inplace=True)
mean_df.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df[name] = train_val_df.groupby('Sample_id')[name].transform('mean')
# /tmp/ipykernel_11161/649964028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.drop_duplicates('Sample_id', inplace=True)
# /tmp/ipykernel_11161/649964028.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_df.sort_values(by='Sample_id', inplace=True)

# %%
y_test_df = pd.DataFrame(y_test.cpu())
y_test_df.columns = elements_names
y_test_df.insert(0, 'Sample_id', test_order)
y_test_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Reducing to some subset

# %%
from itertools import chain, combinations

def powerset(iterable):
    "list(powerset([1,2,3])) --> [(), (1,), (2,), (3,), (1,2), (1,3), (2,3), (1,2,3)]"
    s = list(iterable)
    return chain.from_iterable(list(combinations(s, r)) for r in range(len(s)+1))

# %% [markdown]
# #### Checking if there is any chance for it to work: if classes in y_test are close to means of classes in train_val set

# %%
elements_to_keep
# Out:
# ['Al', 'S', 'Cr', 'Mn', 'Co', 'Cu', 'Zn', 'Pb']

# %%
acc = dict()
for element in list(powerset(elements_to_keep)):
    el_list = list(element)
    closest = []
    if len(element)>0:
        for i in range(y_test_df.shape[0]):
            which_row = (abs(y_test_df[el_list].iloc[i] - mean_df[el_list].iloc[:])).sum(1).idxmin()
            closest.append(mean_df.iloc[which_row]['Sample_id'])
        y_test_df['Closest'] = closest
        y_test_df['Closest'] = y_test_df['Closest'].astype(str)
        y_test_df['Sample_id'] = y_test_df['Sample_id'].astype(str)
        el_list_name = '_'.join(el_list)
        acc[el_list_name] = y_test_df[y_test_df['Sample_id'] == y_test_df['Closest']].shape[0] / len(closest)

# %%
acc
# Out:
# {'Al': 0.015017064846416382,
#  'S': 0.00955631399317406,
#  'Cr': 0.017064846416382253,
#  'Mn': 0.012286689419795221,
#  'Co': 0.014334470989761093,
#  'Cu': 0.006825938566552901,
#  'Zn': 0.010238907849829351,
#  'Pb': 0.017064846416382253,
#  'Al_S': 0.039590443686006824,
#  'Al_Cr': 0.05187713310580205,
#  'Al_Mn': 0.05324232081911263,
#  'Al_Co': 0.039590443686006824,
#  'Al_Cu': 0.059385665529010236,
#  'Al_Zn': 0.05597269624573379,
#  'Al_Pb': 0.06689419795221843,
#  'S_Cr': 0.050511945392491465,
#  'S_Mn': 0.04368600682593857,
#  'S_Co': 0.032081911262798635,
#  'S_Cu': 0.048464163822525594,
#  'S_Zn': 0.06075085324232082,
#  'S_Pb': 0.04778156996587031,
#  'Cr_Mn': 0.049829351535836175,
#  'Cr_Co': 0.040273037542662114,
#  'Cr_Cu': 0.06348122866894199,
#  'Cr_Zn': 0.049829351535836175,
#  'Cr_Pb': 0.05460750853242321,
#  'Mn_Co': 0.034129692832764506,
#  'Mn_Cu': 0.06484641638225255,
#  'Mn_Zn': 0.05460750853242321,
#  'Mn_Pb': 0.06143344709897611,
#  'Co_Cu': 0.049146757679180884,
#  'Co_Zn': 0.04641638225255973,
#  'Co_Pb': 0.042320819112627986,
#  'Cu_Zn': 0.06621160409556313,
#  'Cu_Pb': 0.07713310580204778,
#  'Zn_Pb': 0.06484641638225255,
#  'Al_S_Cr': 0.07986348122866894,
#  'Al_S_Mn': 0.09146757679180888,
#  'Al_S_Co': 0.06552901023890785,
#  'Al_S_Cu': 0.1037542662116041,
#  'Al_S_Zn': 0.10102389078498293,
#  'Al_S_Pb': 0.10238907849829351,
#  'Al_Cr_Mn': 0.08395904436860069,
#  'Al_Cr_Co': 0.06279863481228669,
#  'Al_Cr_Cu': 0.10034129692832765,
#  'Al_Cr_Zn': 0.08805460750853242,
#  'Al_Cr_Pb': 0.0901023890784983,
#  'Al_Mn_Co': 0.07440273037542662,
#  'Al_Mn_Cu': 0.12354948805460751,
#  'Al_Mn_Zn': 0.10170648464163823,
#  'Al_Mn_Pb': 0.1242320819112628,
#  'Al_Co_Cu': 0.089419795221843,
#  'Al_Co_Zn': 0.09078498293515358,
#  'Al_Co_Pb': 0.07508532423208192,
#  'Al_Cu_Zn': 0.12218430034129693,
#  'Al_Cu_Pb': 0.1372013651877133,
#  'Al_Zn_Pb': 0.12764505119453926,
#  'S_Cr_Mn': 0.09965870307167235,
#  'S_Cr_Co': 0.08122866894197953,
#  'S_Cr_Cu': 0.11399317406143344,
#  'S_Cr_Zn': 0.10853242320819112,
#  'S_Cr_Pb': 0.09761092150170649,
#  'S_Mn_Co': 0.07440273037542662,
#  'S_Mn_Cu': 0.10921501706484642,
#  'S_Mn_Zn': 0.10784982935153584,
#  'S_Mn_Pb': 0.10443686006825939,
#  'S_Co_Cu': 0.08327645051194539,
#  'S_Co_Zn': 0.09078498293515358,
#  'S_Co_Pb': 0.08054607508532423,
#  'S_Cu_Zn': 0.11467576791808874,
#  'S_Cu_Pb': 0.12286689419795221,
#  'S_Zn_Pb': 0.12354948805460751,
#  'Cr_Mn_Co': 0.08122866894197953,
#  'Cr_Mn_Cu': 0.10170648464163823,
#  'Cr_Mn_Zn': 0.10784982935153584,
#  'Cr_Mn_Pb': 0.09215017064846416,
#  'Cr_Co_Cu': 0.08327645051194539,
#  'Cr_Co_Zn': 0.09761092150170649,
#  'Cr_Co_Pb': 0.08191126279863481,
#  'Cr_Cu_Zn': 0.1174061433447099,
#  'Cr_Cu_Pb': 0.11808873720136519,
#  'Cr_Zn_Pb': 0.10580204778156997,
#  'Mn_Co_Cu': 0.08737201365187713,
#  'Mn_Co_Zn': 0.08395904436860069,
#  'Mn_Co_Pb': 0.089419795221843,
#  'Mn_Cu_Zn': 0.11877133105802047,
#  'Mn_Cu_Pb': 0.12491467576791809,
#  'Mn_Zn_Pb': 0.11262798634812286,
#  'Co_Cu_Zn': 0.10648464163822526,
#  'Co_Cu_Pb': 0.09761092150170649,
#  'Co_Zn_Pb': 0.0962457337883959,
#  'Cu_Zn_Pb': 0.1310580204778157,
#  'Al_S_Cr_Mn': 0.12696245733788397,
#  'Al_S_Cr_Co': 0.0962457337883959,
#  'Al_S_Cr_Cu': 0.14266211604095563,
#  'Al_S_Cr_Zn': 0.13651877133105803,
#  'Al_S_Cr_Pb': 0.12764505119453926,
#  'Al_S_Mn_Co': 0.11194539249146758,
#  'Al_S_Mn_Cu': 0.1645051194539249,
#  'Al_S_Mn_Zn': 0.14812286689419796,
#  'Al_S_Mn_Pb': 0.15494880546075085,
#  'Al_S_Co_Cu': 0.13037542662116042,
#  'Al_S_Co_Zn': 0.13037542662116042,
#  'Al_S_Co_Pb': 0.11262798634812286,
#  'Al_S_Cu_Zn': 0.1590443686006826,
#  'Al_S_Cu_Pb': 0.1802047781569966,
#  'Al_S_Zn_Pb': 0.1658703071672355,
#  'Al_Cr_Mn_Co': 0.10238907849829351,
#  'Al_Cr_Mn_Cu': 0.14744027303754267,
#  'Al_Cr_Mn_Zn': 0.12491467576791809,
#  'Al_Cr_Mn_Pb': 0.13310580204778158,
#  'Al_Cr_Co_Cu': 0.11399317406143344,
#  'Al_Cr_Co_Zn': 0.11535836177474403,
#  'Al_Cr_Co_Pb': 0.10648464163822526,
#  'Al_Cr_Cu_Zn': 0.14061433447098975,
#  'Al_Cr_Cu_Pb': 0.15426621160409557,
#  'Al_Cr_Zn_Pb': 0.13583617747440274,
#  'Al_Mn_Co_Cu': 0.13037542662116042,
#  'Al_Mn_Co_Zn': 0.12832764505119454,
#  'Al_Mn_Co_Pb': 0.12901023890784982,
#  'Al_Mn_Cu_Zn': 0.16655290102389078,
#  'Al_Mn_Cu_Pb': 0.1802047781569966,
#  'Al_Mn_Zn_Pb': 0.16518771331058021,
#  'Al_Co_Cu_Zn': 0.14675767918088736,
#  'Al_Co_Cu_Pb': 0.13515358361774743,
#  'Al_Co_Zn_Pb': 0.14061433447098975,
#  'Al_Cu_Zn_Pb': 0.1781569965870307,
#  'S_Cr_Mn_Co': 0.11604095563139932,
#  'S_Cr_Mn_Cu': 0.16177474402730374,
#  'S_Cr_Mn_Zn': 0.14948805460750852,
#  'S_Cr_Mn_Pb': 0.14607508532423208,
#  'S_Cr_Co_Cu': 0.12286689419795221,
#  'S_Cr_Co_Zn': 0.14266211604095563,
#  'S_Cr_Co_Pb': 0.12081911262798635,
#  'S_Cr_Cu_Zn': 0.157679180887372,
#  'S_Cr_Cu_Pb': 0.16860068259385666,
#  'S_Cr_Zn_Pb': 0.157679180887372,
#  'S_Mn_Co_Cu': 0.12559726962457338,
#  'S_Mn_Co_Zn': 0.12627986348122866,
#  'S_Mn_Co_Pb': 0.12354948805460751,
#  'S_Mn_Cu_Zn': 0.16040955631399317,
#  'S_Mn_Cu_Pb': 0.18088737201365188,
#  'S_Mn_Zn_Pb': 0.16040955631399317,
#  'S_Co_Cu_Zn': 0.1440273037542662,
#  'S_Co_Cu_Pb': 0.1385665529010239,
#  'S_Co_Zn_Pb': 0.14812286689419796,
#  'S_Cu_Zn_Pb': 0.17474402730375427,
#  'Cr_Mn_Co_Cu': 0.12354948805460751,
#  'Cr_Mn_Co_Zn': 0.12559726962457338,
#  'Cr_Mn_Co_Pb': 0.12764505119453926,
#  'Cr_Mn_Cu_Zn': 0.15426621160409557,
#  'Cr_Mn_Cu_Pb': 0.1583617747440273,
#  'Cr_Mn_Zn_Pb': 0.14334470989761092,
#  'Cr_Co_Cu_Zn': 0.1378839590443686,
#  'Cr_Co_Cu_Pb': 0.1453924914675768,
#  'Cr_Co_Zn_Pb': 0.1385665529010239,
#  'Cr_Cu_Zn_Pb': 0.16928327645051194,
#  'Mn_Co_Cu_Zn': 0.1372013651877133,
#  'Mn_Co_Cu_Pb': 0.1372013651877133,
#  'Mn_Co_Zn_Pb': 0.13037542662116042,
#  'Mn_Cu_Zn_Pb': 0.17337883959044367,
#  'Co_Cu_Zn_Pb': 0.15358361774744028,
#  'Al_S_Cr_Mn_Co': 0.13651877133105803,
#  'Al_S_Cr_Mn_Cu': 0.18430034129692832,
#  'Al_S_Cr_Mn_Zn': 0.17679180887372015,
#  'Al_S_Cr_Mn_Pb': 0.1726962457337884,
#  'Al_S_Cr_Co_Cu': 0.14880546075085324,
#  'Al_S_Cr_Co_Zn': 0.16177474402730374,
#  'Al_S_Cr_Co_Pb': 0.14607508532423208,
#  'Al_S_Cr_Cu_Zn': 0.18225255972696247,
#  'Al_S_Cr_Cu_Pb': 0.19180887372013652,
#  'Al_S_Cr_Zn_Pb': 0.1849829351535836,
#  'Al_S_Mn_Co_Cu': 0.16245733788395905,
#  'Al_S_Mn_Co_Zn': 0.157679180887372,
#  'Al_S_Mn_Co_Pb': 0.15494880546075085,
#  'Al_S_Mn_Cu_Zn': 0.19795221843003413,
#  'Al_S_Mn_Cu_Pb': 0.2204778156996587,
#  'Al_S_Mn_Zn_Pb': 0.20409556313993174,
#  'Al_S_Co_Cu_Zn': 0.17064846416382254,
#  'Al_S_Co_Cu_Pb': 0.16928327645051194,
#  'Al_S_Co_Zn_Pb': 0.17747440273037543,
#  'Al_S_Cu_Zn_Pb': 0.21843003412969283,
#  'Al_Cr_Mn_Co_Cu': 0.1453924914675768,
#  'Al_Cr_Mn_Co_Zn': 0.14948805460750852,
#  'Al_Cr_Mn_Co_Pb': 0.14812286689419796,
#  'Al_Cr_Mn_Cu_Zn': 0.17474402730375427,
#  'Al_Cr_Mn_Cu_Pb': 0.20136518771331058,
#  'Al_Cr_Mn_Zn_Pb': 0.16518771331058021,
#  'Al_Cr_Co_Cu_Zn': 0.1658703071672355,
#  'Al_Cr_Co_Cu_Pb': 0.16791808873720138,
#  'Al_Cr_Co_Zn_Pb': 0.15699658703071673,
#  'Al_Cr_Cu_Zn_Pb': 0.19044368600682593,
#  'Al_Mn_Co_Cu_Zn': 0.1720136518771331,
#  'Al_Mn_Co_Cu_Pb': 0.17406143344709898,
#  'Al_Mn_Co_Zn_Pb': 0.16860068259385666,
#  'Al_Mn_Cu_Zn_Pb': 0.2143344709897611,
#  'Al_Co_Cu_Zn_Pb': 0.1849829351535836,
#  'S_Cr_Mn_Co_Cu': 0.17474402730375427,
#  'S_Cr_Mn_Co_Zn': 0.1658703071672355,
#  'S_Cr_Mn_Co_Pb': 0.16040955631399317,
#  'S_Cr_Mn_Cu_Zn': 0.19795221843003413,
#  'S_Cr_Mn_Cu_Pb': 0.20955631399317406,
#  'S_Cr_Mn_Zn_Pb': 0.18430034129692832,
#  'S_Cr_Co_Cu_Zn': 0.1863481228668942,
#  'S_Cr_Co_Cu_Pb': 0.17747440273037543,
#  'S_Cr_Co_Zn_Pb': 0.1863481228668942,
#  'S_Cr_Cu_Zn_Pb': 0.2197952218430034,
#  'S_Mn_Co_Cu_Zn': 0.16655290102389078,
#  'S_Mn_Co_Cu_Pb': 0.1726962457337884,
#  'S_Mn_Co_Zn_Pb': 0.16996587030716723,
#  'S_Mn_Cu_Zn_Pb': 0.21706484641638224,
#  'S_Co_Cu_Zn_Pb': 0.18907849829351536,
#  'Cr_Mn_Co_Cu_Zn': 0.17064846416382254,
#  'Cr_Mn_Co_Cu_Pb': 0.17474402730375427,
#  'Cr_Mn_Co_Zn_Pb': 0.16791808873720138,
#  'Cr_Mn_Cu_Zn_Pb': 0.20273037542662117,
#  'Cr_Co_Cu_Zn_Pb': 0.18703071672354948,
#  'Mn_Co_Cu_Zn_Pb': 0.16996587030716723,
#  'Al_S_Cr_Mn_Co_Cu': 0.18907849829351536,
#  'Al_S_Cr_Mn_Co_Zn': 0.1849829351535836,
#  'Al_S_Cr_Mn_Co_Pb': 0.17610921501706484,
#  'Al_S_Cr_Mn_Cu_Zn': 0.221160409556314,
#  'Al_S_Cr_Mn_Cu_Pb': 0.23003412969283277,
#  'Al_S_Cr_Mn_Zn_Pb': 0.21774744027303755,
#  'Al_S_Cr_Co_Cu_Zn': 0.19863481228668942,
#  'Al_S_Cr_Co_Cu_Pb': 0.19863481228668942,
#  'Al_S_Cr_Co_Zn_Pb': 0.2,
#  'Al_S_Cr_Cu_Zn_Pb': 0.24232081911262798,
#  'Al_S_Mn_Co_Cu_Zn': 0.2,
#  'Al_S_Mn_Co_Cu_Pb': 0.20136518771331058,
#  'Al_S_Mn_Co_Zn_Pb': 0.20136518771331058,
#  'Al_S_Mn_Cu_Zn_Pb': 0.2416382252559727,
#  'Al_S_Co_Cu_Zn_Pb': 0.21706484641638224,
#  'Al_Cr_Mn_Co_Cu_Zn': 0.19044368600682593,
#  'Al_Cr_Mn_Co_Cu_Pb': 0.1945392491467577,
#  'Al_Cr_Mn_Co_Zn_Pb': 0.1849829351535836,
#  'Al_Cr_Mn_Cu_Zn_Pb': 0.2273037542662116,
#  'Al_Cr_Co_Cu_Zn_Pb': 0.20409556313993174,
#  'Al_Mn_Co_Cu_Zn_Pb': 0.21023890784982935,
#  'S_Cr_Mn_Co_Cu_Zn': 0.20477815699658702,
#  'S_Cr_Mn_Co_Cu_Pb': 0.21092150170648463,
#  'S_Cr_Mn_Co_Zn_Pb': 0.2054607508532423,
#  'S_Cr_Mn_Cu_Zn_Pb': 0.24914675767918087,
#  'S_Cr_Co_Cu_Zn_Pb': 0.23139931740614333,
#  'S_Mn_Co_Cu_Zn_Pb': 0.2129692832764505,
#  'Cr_Mn_Co_Cu_Zn_Pb': 0.20819112627986347,
#  'Al_S_Cr_Mn_Co_Cu_Zn': 0.2197952218430034,
#  'Al_S_Cr_Mn_Co_Cu_Pb': 0.23686006825938566,
#  'Al_S_Cr_Mn_Co_Zn_Pb': 0.22525597269624573,
#  'Al_S_Cr_Mn_Cu_Zn_Pb': 0.26348122866894197,
#  'Al_S_Cr_Co_Cu_Zn_Pb': 0.24232081911262798,
#  'Al_S_Mn_Co_Cu_Zn_Pb': 0.2354948805460751,
#  'Al_Cr_Mn_Co_Cu_Zn_Pb': 0.22525597269624573,
#  'S_Cr_Mn_Co_Cu_Zn_Pb': 0.24709897610921502,
#  'Al_S_Cr_Mn_Co_Cu_Zn_Pb': 0.2593856655290102}

# %%
closest = []
for i in range(y_test_df.shape[0]):
    which_row = (abs(y_test_df.iloc[i, 1:] - mean_df.iloc[:,1:])).sum(1).idxmin()
    closest.append(mean_df.iloc[which_row]['Sample_id'])

# %%
len(closest)
# Out:
# 1465

# %%
y_test_df['Closest'] = closest
y_test_df['Closest'] = y_test_df['Closest'].astype(str)
y_test_df['Sample_id'] = y_test_df['Sample_id'].astype(str)

# %%
y_test_df[y_test_df['Sample_id'] == y_test_df['Closest']].shape[0]
# Out:
# 380

# %%
y_test_df[y_test_df['Sample_id'] == y_test_df['Closest']].shape[0] / len(closest)
# Out:
# 0.2593856655290102
